# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('hotel_bookings 2.csv')

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
df.tail(10)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119380             August                        35
# 119381             August                        35
# 119382             August                        35
# 119383             August                        35
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df['reservation_status_date']=pd.to_datetime(df['reservation_status_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
df['country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %%
df.describe(include='object').columns
# Out:
# Index(['hotel', 'arrival_date_month', 'meal', 'country', 'market_segment',
#        'distribution_channel', 'reserved_room_type', 'assigned_room_type',
#        'deposit_type', 'customer_type', 'reservation_status'],
#       dtype='object')

# %%
df.describe().columns
# Out:
# Index(['is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_week_number', 'arrival_date_day_of_month',
#        'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children',
#        'babies', 'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'booking_changes',
#        'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
#        'total_of_special_requests', 'month'],
#       dtype='object')

# %% [markdown]
# # knowing unique values and their counts in column having integer data type

# %%
for i in df.describe().columns:
    n=df[i].unique()
    print(i)
    print(n)
    print(len(n))
    print('-'*50)
# Out:
# is_canceled
# [0 1]
# 2
# --------------------------------------------------
# lead_time
# [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99  95  96  69  45  40  15  36  43  70  16 107  47 113  90
#   50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364 324
#   79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8 100
#   44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112  65
#   67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108 106
#   31  87  41 304 117  59  53  58 116  42 321  38 118  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
#  172 171 145 121 178 305 173 152 354 347 158 185 349 183 352 177 200 192
# ...

# %% [markdown]
# # knowing unique values and their counts in column having object data type

# %%
for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
    print(len(df[col].unique()))
    print('-'*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# 2
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# 12
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# 5
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' 'ROU' 'NOR' 'OMN' 'ARG' 'POL' 'DEU'
#  'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST' 'CZE'
#  'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR' 'UKR'
#  'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO' 'ISR'
#  'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM' 'HRV'
#  'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY' 'KWT'
#  'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN' 'SYC'
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# # dropping columns having very high missing values

# %%
df.drop(['company', 'agent'], axis = 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# hotel                               0
# is_canceled                         0
# lead_time                           0
# arrival_date_year                   0
# arrival_date_month                  0
# arrival_date_week_number            0
# arrival_date_day_of_month           0
# stays_in_weekend_nights             0
# stays_in_week_nights                0
# adults                              0
# children                            4
# babies                              0
# meal                                0
# country                           488
# market_segment                      0
# distribution_channel                0
# is_repeated_guest                   0
# previous_cancellations              0
# previous_bookings_not_canceled      0
# reserved_room_type                  0
# assigned_room_type                  0
# booking_changes                     0
# deposit_type                        0
# days_in_waiting_list                0
# customer_type                       0
# ...

# %% [markdown]
# # dropping rows having missing values

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Length: 118898, dtype: bool

# %%
duplicated_rows = df.duplicated()
number_of_duplicate_rows = duplicated_rows.sum()
print(number_of_duplicate_rows)
# Out:
# 31984

# %% [markdown]
# # dropping duplicates values

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# # making boxplot for adr column

# %%
df.boxplot(column='adr')
plt.title("Box Plot of 'adr' Column")
plt.ylabel("adr Values")
plt.show()

# %% [markdown]
# # making boxplot for data

# %%
df.boxplot()
plt.title("Box Plot of Numerical Columns")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

# Display the plot (required for Jupyter Notebook)
plt.show()

# %% [markdown]
# # finding outliers

# %%
q1 = df['adr'].quantile(0.25)
q3 = df['adr'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers_iqr = df[(df['adr'] < lower_bound) | (df['adr'] > upper_bound)]

# %%
outliers_iqr
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 396     Resort Hotel            0        317               2015
# 523     Resort Hotel            0          0               2015
# 526     Resort Hotel            0         73               2015
# 584     Resort Hotel            1         28               2015
# 641     Resort Hotel            1         22               2015
# ...              ...          ...        ...                ...
# 119152    City Hotel            0         29               2017
# 119247    City Hotel            0        140               2017
# 119289    City Hotel            0         25               2017
# 119339    City Hotel            0        110               2017
# 119365    City Hotel            0         54               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 396                  July                        29
# 523                  July                        29
# ...

# %%
outliers_iqr.shape
# Out:
# (2504, 30)

# %% [markdown]
# # replacing outliers with median

# %%
df.loc[outliers_iqr.index, 'adr'] = df['adr'].median()

# %%
outliers_iqr.shape
# Out:
# (2504, 30)

# %%
outliers_iqr = df[(df['adr'] < lower_bound) | (df['adr'] > upper_bound)]

# %%
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date]
# Index: []
#
# [0 rows x 30 columns]

# %%
df['is_canceled'].value_counts()
# Out:
# 0    62931
# 1    23983
# Name: is_canceled, dtype: int64

# %%
df['is_canceled'].value_counts(normalize = True)
# Out:
# 0    0.724061
# 1    0.275939
# Name: is_canceled, dtype: float64

# %% [markdown]
# # making countplot of is_cancelled column

# %%
sns.countplot(x='is_canceled', data=df)   # countplot hum tab banate hai jab data ki unique values limited ho 
plt.title("Cancellation Count")
plt.xlabel("Cancellation Status")
plt.ylabel("Count")

# Display the plot (required for Jupyter Notebook)
plt.show()

# %%
l
# Out:
# 0    62931
# 1    23983
# Name: is_canceled, dtype: int64

# %%
l.index
# Out:
# Int64Index([0, 1], dtype='int64')

# %% [markdown]
# # How many booking got cancelled ?

# %%
l1=["not canceled","Canceled"]  # YE HUME SEQUENCE MEIN DENA HOTA HAI 
l=df["is_canceled"].value_counts()
l
plt.pie(l,labels=l1,autopct='%.2f');
plt.legend()
plt.title("Canceled or not")
plt.show()

# %% [markdown]
# Around 28 percentage booking got cancelled

# %% [markdown]
# # How many hotel room canceled after booking in different type of hotels ?

# %%
sns.countplot(x='hotel',hue='is_canceled',data=df)
plt.title('Reservation status in different hotels', size = 20)
plt.xlabel('hotel')
plt.ylabel('number of reservations')
plt.legend(['not canceled', 'canceled'])
plt.show()

# %% [markdown]
# In city hotel more percentage of rooms is got canacelled than resort hotel

# %%
subset = df.loc[df['hotel'] == 'City Hotel', 'is_canceled'].value_counts()

print(subset)
# Out:
# 0    37365
# 1    16039
# Name: is_canceled, dtype: int64

# %%
subset1 = df.loc[df['hotel'] == 'City Hotel', 'is_canceled'].value_counts(normalize = True)

print(subset1)
# Out:
# 0    0.699667
# 1    0.300333
# Name: is_canceled, dtype: float64

# %%
subset1 = df.loc[df['hotel'] == 'Resort Hotel', 'is_canceled'].value_counts(normalize = True)

print(subset1)
# Out:
# 0    0.762936
# 1    0.237064
# Name: is_canceled, dtype: float64

# %%
df['month'] = df['reservation_status_date'].dt.month

# %% [markdown]
# # WHAT IS RESERVATION STATUS PER MONTH

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.countplot(data = df ,x = 'month', hue = 'is_canceled')  # agar bahut jyada value hogi yani continuous hoga toh nhi banega 

       

plt.show()

# %% [markdown]
# We have developed the grouped bar graph to analyze the months with the highest and lowest reservation levels according to reservation status. we can see in august months number of bookings confirmed is high and number of booking cancellation is low. and march has highest number of booking cancellation

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x='month', hue='is_canceled', palette='Set1', dodge=True)

total = len(df)
for p in ax.patches:
    height = p.get_height()
    if pd.notna(height):
        percentage = f'{(height / total) * 100:.1f}%'
        x = p.get_x() + p.get_width() / 2.
        y = p.get_y() + height
        ax.annotate(percentage, (x, y), ha='center', va='bottom', fontsize=8)

plt.xlabel('Month')
plt.ylabel('Count')
plt.title('Countplot with Percentages Between Months and Cancellation Status')
plt.legend(title='Cancellation Status')
plt.show()

# %%
data_to_plot
# Out:
#     month        adr
# 0       1  234299.65
# 1       2  241753.77
# 2       3  270815.92
# 3       4  260559.03
# 4       5  254462.93
# 5       6  258834.01
# 6       7  247926.77
# 7       8  198516.46
# 8       9  187608.28
# 9      10  178406.11
# 10     11  162043.78
# 11     12  171573.39

# %% [markdown]
# # what is the relationship between adr and cancellation

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named df
data_to_plot = df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index()

sns.barplot(x='month', y='adr', data=data_to_plot)
plt.show()

# %% [markdown]
# This bar graph demonstrates that cancellations are most common when prices are greatest and are least common when they are lowest. Therefore, the cost of the accommodation is solely responsible for the cancellation.

# %%
cancelled_data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 8       Resort Hotel            1         85               2015
# 9       Resort Hotel            1         75               2015
# 10      Resort Hotel            1         23               2015
# 27      Resort Hotel            1         60               2015
# 32      Resort Hotel            1         96               2015
# ...              ...          ...        ...                ...
# 110280    City Hotel            1        132               2017
# 111355    City Hotel            1          4               2017
# 111924    City Hotel            1          7               2017
# 111925    City Hotel            1          6               2017
# 117295    City Hotel            1          0               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 8                    July                        27
# 9                    July                        27
# ...

# %% [markdown]
# # which country has the highest reservation canceled.

# %%
top_10_country
# Out:
# PRT    9783
# GBR    1985
# ESP    1862
# FRA    1733
# ITA    1075
# DEU    1053
# BRA     727
# IRL     668
# USA     459
# BEL     411
# Name: country, dtype: int64

# %%
top_10_country.index
# Out:
# Index(['PRT', 'GBR', 'ESP', 'FRA', 'ITA', 'DEU', 'BRA', 'IRL', 'USA', 'BEL'], dtype='object')

# %%
cancelled_data = df[df['is_canceled'] == 1]   # agar apko filter data chahiye but aap data mein change nui karna chAHATE TO KISI DUSRE VARIABLE MEIN STORE KAR KE USE KAR SAKTE HAI 
top_10_country = cancelled_data['country'].value_counts()[:10]

plt.title('Top 10 countries with reservation canceled')
plt.pie(top_10_country,  autopct = '%.2f',labels = top_10_country.index)
plt.show()

# %% [markdown]
# The top country is Portugal with the highest number of cancellations.

# %% [markdown]
# # Which market_segment have maximum values ?

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        51534
# Offline TA/TO    13849
# Direct           11645
# Groups            4936
# Corporate         4025
# Complementary      698
# Aviation           227
# Name: market_segment, dtype: int64

# %% [markdown]
# online TA market_segment have maximum values and it is more than 50 %

# %%
df['market_segment'].value_counts(normalize = True)
# Out:
# Online TA        0.592931
# Offline TA/TO    0.159341
# Direct           0.133983
# Groups           0.056792
# Corporate        0.046310
# Complementary    0.008031
# Aviation         0.002612
# Name: market_segment, dtype: float64

# %% [markdown]
# # Which market_segment have maximum canacelled  values ?

# %%
cancelled_data['market_segment'].value_counts(normalize = True)
# Out:
# Online TA        0.760664
# Offline TA/TO    0.085644
# Direct           0.071843
# Groups           0.055664
# Corporate        0.020723
# Complementary    0.003586
# Aviation         0.001876
# Name: market_segment, dtype: float64

# %% [markdown]
# online TA have maximum  canacelled values

# %%
sns.countplot(x = 'reserved_room_type', hue = 'is_canceled', data = df)  
plt.show()

# %% [markdown]
# # which type of deposit is prefered?

# %%
sns.countplot(x = 'deposit_type', hue = 'is_canceled', data = df)  
plt.show()

# %% [markdown]
# The preferred deposit type is No Deposit

# %%
sns.countplot(x = 'customer_type', hue = 'is_canceled', data = df[df['is_canceled'] == 0])  
plt.show()

# %%
sns.countplot(x = 'customer_type', hue = 'is_canceled', data = df[df['is_canceled'] == 1]) 
plt.show()

# %%
sns.countplot(x = 'customer_type', hue = 'is_canceled', data = df)  
plt.show()

# %% [markdown]
# # Which type of booking (deposit type) is prefered ?

# %%
df["deposit_type"].unique()
# Out:
# array(['No Deposit', 'Refundable', 'Non Refund'], dtype=object)

# %%
sns.countplot(x='deposit_type', data=df)
plt.title("DEPOSIT TYPE")
plt.xlabel('deposit_type')
plt.ylabel("Count")
plt.show()

# %% [markdown]
# According to the data the deposit type is no deposit.
# And Refundable is not visible in the graph so it's almost 0

# %% [markdown]
# # Which type of customer is highest ?

# %%
df["customer_type"].unique()
# Out:
# array(['Transient', 'Contract', 'Transient-Party', 'Group'], dtype=object)

# %%
sns.countplot(x='customer_type', data=df)
plt.title("DEPOSIT TYPE")
plt.xlabel('deposit_type')
plt.ylabel("Count")
plt.show()

# %% [markdown]
# we can see from this graph transient type have highest number of customer

# %% [markdown]
# # Which distribution have maximum values ?

# %%
sns.countplot(x='distribution_channel', data=df)
plt.title("Distribution_Channel")
plt.xlabel('distribution_channel')
plt.ylabel("Count")
plt.show()

# %% [markdown]
# TA/TO distribution channel is mostly used
# GDS is less used

# %% [markdown]
# # Which type of room is reserved ?

# %%
sns.countplot(x='reserved_room_type', data=df)
plt.title("Reserved_Room_Type")
plt.xlabel('reserved_room_type')
plt.ylabel("Count")
plt.show()

# %% [markdown]
# We can see that mostly A type of room get reserved

# %% [markdown]
# # Which kind of marget segment with the maximum cancelled booking ?

# %%
sns.countplot(x = 'market_segment', data = df, hue = 'hotel')
plt.xlabel('Market segment')
plt.ylabel('Cancel booking')
plt.title('Market segment and hotel')
plt.show()

# %% [markdown]
# online TA have maximum cancelled bookings

# %% [markdown]
# # What kind of room is assigned coresponding with hotel type ?

# %%
sns.countplot(data=df,x='hotel',hue='assigned_room_type')
plt.xlabel('assigned_room_type')
plt.ylabel('hotel')
plt.title('Hotel and Assigned room type')
plt.show()

# %% [markdown]
# In both resort and city hotel the most preferred room type is A

# %% [markdown]
# # WHAT IS THE RELATIONSHIP BETWEEN ADR AND CANCELLATION?

# %%
cancelled_data = df[df['is_canceled'] == 1]
cancelled_df_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace = True)
cancelled_df_adr.sort_values('reservation_status_date', inplace = True)

not_cancelled_data = df[df['is_canceled'] == 0]
not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace = True)
not_cancelled_df_adr.sort_values('reservation_status_date', inplace = True)

plt.figure(figsize = (20,6))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'], label = 'not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'], label = 'cancelled')
plt.legend()
plt.show()

# %% [markdown]
# As seen in the graph, reservations are canceled when the average daily rate is higher than when it is not canceled.
# It clearly proves all the above analysis, that the higher price leads to higher cancellation.

# %%
cancelled_df_adr
# Out:
#     reservation_status_date         adr
# 0                2014-10-17   62.800000
# 1                2014-11-18    0.000000
# 2                2015-01-01   62.104444
# 3                2015-01-05  108.930000
# 4                2015-01-06  107.678333
# ..                      ...         ...
# 897              2017-12-04  126.927037
# 898              2017-12-05  108.620484
# 899              2017-12-06  138.514333
# 900              2017-12-07  135.204000
# 901              2017-12-08  133.364000
#
# [902 rows x 2 columns]

# %%
not_cancelled_df_adr
# Out:
#     reservation_status_date         adr
# 0                2015-01-07   31.650000
# 1                2015-01-08  137.896591
# 2                2015-01-09  113.600625
# 3                2015-01-10   86.375250
# 4                2015-01-11   61.995795
# ..                      ...         ...
# 800              2017-12-05  113.035465
# 801              2017-12-06  123.514943
# 802              2017-12-07  125.097333
# 803              2017-12-08  137.805100
# 804              2017-12-09  153.570000
#
# [805 rows x 2 columns]

# %%
resort_hotel = df[df['hotel'] == 'Resort Hotel']

# %%
resort_hotel
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 1      Resort Hotel            0        737               2015
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 40055  Resort Hotel            0        212               2017
# 40056  Resort Hotel            0        169               2017
# 40057  Resort Hotel            0        204               2017
# 40058  Resort Hotel            0        211               2017
# 40059  Resort Hotel            0        161               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %%
city_hotel = df[df['hotel'] == 'City Hotel']
city_hotel
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 40060   City Hotel            0          6               2015
# 40061   City Hotel            1         88               2015
# 40062   City Hotel            1         65               2015
# 40063   City Hotel            1         92               2015
# 40064   City Hotel            1        100               2015
# ...            ...          ...        ...                ...
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 40060                July                        27
# 40061                July                        27
# 40062                July                        27
# ...

# %%
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
resort_hotel
# Out:
#                                 adr
# reservation_status_date
# 2014-11-18                 0.000000
# 2015-01-01                61.966667
# 2015-01-05               118.936000
# 2015-01-06               133.677143
# 2015-01-07                79.691111
# ...                             ...
# 2017-12-05                91.855075
# 2017-12-06               122.959333
# 2017-12-07               131.526735
# 2017-12-08               142.060000
# 2017-12-09               153.570000
#
# [913 rows x 1 columns]

# %%
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel
# Out:
#                                 adr
# reservation_status_date
# 2014-10-17                62.800000
# 2015-01-01                62.114286
# 2015-01-05                58.900000
# 2015-01-06                71.280000
# 2015-01-07                82.877500
# ...                             ...
# 2017-12-04               123.003205
# 2017-12-05               127.175679
# 2017-12-06               130.111944
# 2017-12-07               125.522527
# 2017-12-08               135.360429
#
# [864 rows x 1 columns]

# %% [markdown]
# # WHICH TYPE OF HOTEL HAVE MORE ADR AND BOOKINGS?

# %%
plt.figure(figsize = (20,8))
plt.title('Average Daily Rate in City and Resort Hotel', fontsize = 30)
plt.plot(resort_hotel.index, resort_hotel['adr'], label = 'Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'], label = 'City Hotel')
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# In comparison to resort hotels, city hotels have more bookings.
# It's possible that resort hotels are more expensive than those in cities.

# %%
city_hotel.reset_index(inplace = True)

# %%
city_hotel
# Out:
#     reservation_status_date         adr
# 0                2014-10-17   62.800000
# 1                2015-01-01   62.114286
# 2                2015-01-05   58.900000
# 3                2015-01-06   71.280000
# 4                2015-01-07   82.877500
# ..                      ...         ...
# 859              2017-12-04  123.003205
# 860              2017-12-05  127.175679
# 861              2017-12-06  130.111944
# 862              2017-12-07  125.522527
# 863              2017-12-08  135.360429
#
# [864 rows x 2 columns]

# %% [markdown]
# # where maximum leading time lie?

# %%
sns.distplot(df["lead_time"])
plt.show()

# %% [markdown]
# We can see most of the leading time is between 0-200

# %% [markdown]
# # suggestions

# %% [markdown]
# 1.Cancellation rates rise as the price does. In order to prevent cancellations of reservations, hotels could work on their pricing strategies and try to lower the rates for specific hotels based on locations. They can also provide some discounts to the consumers.

# %% [markdown]
# 2.In the month of ,March hotels can start campaigns or marketing with a reasonable amount
# to increase their revenue as the cancellation is the highest in this month. as th

# %% [markdown]
# 3   They can also increase the quality of their hotels and their services mainly in Portugal to reduce the cancellation rate.

# %% [markdown]
# 4 As the ratio of the cancellation and not cancellation of the resort hotel is higher in the resort hotel than the city hotels.
# So the city hotels should provide a reasonable discount on the room prices on weekends or on holidays.

# %% [markdown]
# 5 online TA have maximum  canacelled values.Approx 76% from online TA cancelled further
# so we should give instruction to online TA to give genuine information to customer
# so customer will not cancel further

# %% [markdown]
# 6 We can see that mostly A type of room get reserved . so hotels should focus on to increase quality or quantity of room type A

# %% [markdown]
# 7 we can see transient type have highest number of customer.
# so hotels should focus more on trasnient type of customer  to give better services and good prices

# %% [markdown]
# 8 The preferred deposit type is No Deposit
# so hotels should also prefer No Deposit type to its customers
